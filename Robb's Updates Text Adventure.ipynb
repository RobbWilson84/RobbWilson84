# %% [markdown]
# <a href="https://colab.research.google.com/github/RobbWilson84/RobbWilson84/blob/main/Robb's%20Updates%20Text%20Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What is a Text Based Adventure Game?
# ---
#
# Early computer games did not have the graphics capabilities or software to create games as we know them now.  This is a good introduction to early computer gaming so they can see how game design and technology has moved on, but it is also an excellent way to develop and consolidate Python 3 skills while having some fun.  The game develops skills for:
#
# * functions (writing, calling and passing in arguments)
# * taking input from the user
# * print()
# * if, elif, else
# * equality (==)
# * .lower() method to convert user input to lower case
# * order of code
#
# # Example of one of the first games
# ---
# This is an example of one of the first computer games online.  It might be good to just have a look:
#
# http://textadventures.co.uk/games/play/5zyoqrsugeopel3ffhz_vq
#
# The link to a flow chart for a simple text-based-adventure game is here.  It has been based on an exercise from codingpie.com.
#
# The game uses a number of rooms and choices / decisions to be made by the user. It would be a good introduction to code this and get the idea before moving on to designing your own game and coding it.
#
# https://drive.google.com/file/d/1ZyJ3beAgJukHRzRQynCSgEUYKjHhs5ma/view?usp=sharing
#
# Learners can have a lot of fun doing this.
#
# # Requirements
# ____
# In this example the following are the functions that are required:
#
# ```
# start()
# load_bear_room()
# load_monster_room()
# load_diamond_room()
# game_over()
# win()
# ```
#
# Each room should start with the intro to the room and provide the choices for the user
#
# The decisions are the choices offered to the user, and depending on the choice they make, the relevant function is loaded.
#
# The order of the functions is important.  For example, if the user chooses option 1 from the load_bear_room(), the game_over() function will be called.  Therefore the game_over() function must be written in the code above the load_bear_room() function, otherwise you will get an error message.
#
# It is good practice to create all your functions in advance and to use pass so the function does not try and run.
#
# ```
# def start():
#   pass
# ```
#
# Have a go at creating this text-based adventure game in the cell below.

# %% [markdown]
# # Create Your Adventure
# _____
#
# Use the cell below to create your own game as wild as your imagination.

# %%
def start():
   #change to black
  print("\033[30m \n")
  print("welcome! You find yourself trapped in side of of an abandoned mansion")
  print("It's very dark but you make out three doors in front of you")
  print("Where would you like to go?")
  print("1 for hall")
  print("2 for dungeon")
  print("3 for attic")
  option = True
  while option == True:
    answer = int(input("option 1 or 2 or 3 ? "))
    if answer == 1:
    #change to green
      print("\033[1;32m let's go to the main hall  \n")
      main_hall()      
    elif answer == 2:
      dungeon_deadend()
    elif answer == 3:
      attic_deadend()
    else:
      print('try again')
      answer = int(input("option 1 or 2 or 3 ? "))
      option = False
      #change to red
      #print("\u001b[31m That is a red option \n")

def dungeon_deadend():
   #change to yellow
  print("\033[93m \n")
  print("\033[40m")
  print("You find yourself in a very dark room")
  print("You hear strange noises coming from the shadows")
  print("1 for stay")
  print("2 for go")
  stay_go = int(input("Do you stay or go back to the Main Hall? "))

  if stay_go == 1:
      main_hall()
  elif stay_go == 2:
      game_over()
  else:
      print('That is not a valid option')
      dungeon_deadend()

def attic_deadend():
  #change to yellow
  print("\033[93m \n")
  print("\033[40m")
  print("You find yourself in a musty attic room")
  print("a voice starts to speak to you")
  print("1 for listen")
  print("2 to run")
  listen_run = int(input("Do you listen or run? "))

  if listen_run == 1:
    main_hall()
  elif listen_run == 2:
    game_over()
  else:
      print('That is not a valid option')
      attic_deadend()

def main_hall():
  print("You are in the main hall")
  print("In front of you is a large table with some items on it")
  print("You can choose to pick up one of the items")
  print("1 for torch")
  print("2 for key")
  item = int(input("Which item do you pick up"))

  if item == 1:
    attic()
  elif item == 2:
    dungeon()
  else:
      print('That is not a valid option')
      main_hall()


def dungeon():
  #change to yellow
  print("\033[93m \n")
  print("\033[40m")
  print("You are in the dungeon")
  print("In the darkness you notice light coming from a small keyhole")
  print("You begin to hear noise")
  print("1 for key")
  print("2 for run away")
  key_run = int(input("Use your Key or run away? "))

  if key_run == 1:
    win()
  elif key_run == 2:
    game_over()
  else:
      print('That is not a valid option')
      dungeon()


def attic():
  #change to yellow
  print("\033[93m \n")
  print("\033[40m")
  print("You storm into the attic but forget to check your torch for batteries...")
  print("Shadows descend upon you as the room grows even darker")
  shadow_run = int(input("Do you stay (1) or do you run away (2) "))

  if shadow_run == 1:
    game_over()
  elif shadow_run == 2:
    main_hall()
  else:
      print('That is not a valid option')
      attic()


def game_over():
  #change to red
  print("\u001b[31m \n")
  print("something from the dark reaches for you...")
  print("...you try to move but are paralysed with fear!")
  print("The last thing you hear is a loud growl as something bites you")
  word = "Game Over"
  for letter in word:
    print (letter)
  print("1 = Yes and 2 = No")
  play_again = int(input("Would you like to try again? "))

  if play_again == 1:
    start()
  elif play_again == 2:
    print("Thank you for playing")
  else:
      print('That is not a valid option')
      game_over()


def win():
  #change to bold and purple
  print("\033[1m \n")
  print("\033[95m")
  print("\033[40m")
  print("You step into the light...")
  print("Outside of the building you see the sunrise over the hills...")
  print("\033[5m YOU WIN \n")
  print("1 for yes")
  print("2 for no")
  play_again = int(input("Would you like to play again?" ))

  if play_again == 1:
    start()
  elif play_again == 2:
    print("Congratulations...enjoy your life.")
  else:
      print('That is not a valid option')
      play_again()



start()
# Out:
#
#
# welcome! You find yourself trapped in side of of an abandoned mansion
# It's very dark but you make out three doors in front of you
# Where would you like to go?
# 1 for hall
# 2 for dungeon
# 3 for attic

# %%
'''
#class color:   #### I just found this class definition online at stackoverflow - for me this makes the print statements more clearer to see.
   PURPLE = '\033[95m' ### this can be used to change print text colours, font etc
   CYAN = '\033[96m'   #### I have chosen to use bold for the headings in my print statements
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'        
print(color.BOLD +"What does the first 5 rows look like?\n"+ color.END)
print(sea_level.head()) #first 5 rows
print(color.BOLD +"\n\nTechnical summary\n"+ color.END)
print(sea_level.info()) #technical summary
'''
